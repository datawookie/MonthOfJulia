# %% [markdown]
# # Day 2: An IJulia Notebook

# %% [markdown]
# ## Markdown

# %% [markdown]
# You can insert [github flavoured markdown](https://help.github.com/articles/github-flavored-markdown/ "github style markdown"). Mardown cells can contain text, tables, multimedia and even equations.
#
# To edit the contents of a markdown cell, just double-click it.

# %% [markdown]
# ### Equations

# %% [markdown]
# Equations are specified using LaTeX syntax. They can be inline, like $x^2 + \sqrt{x} = 3$, or displayed.
#
# \begin{equation} x^2+\sqrt{x}=3.\end{equation}

# %% [markdown]
# ## Code

# %%
x = 3
# Out:
# 3

# %%
sqrt(x) + rand()
# Out:
# 2.525553237375859

# %% [markdown]
# Unicode characters can be easily entered by typing the corresponding LaTeX code (like \alpha), and then hitting the Tab key.

# %%
"A string with various Unicode characters (α, β and ϕ)."
# Out:
# "A string with various Unicode characters (α, β and ϕ)."

# %%
function square(x)
    return x^2
end
# Out:
# square (generic function with 1 method)

# %%
square(3)
# Out:
# 9

# %%
using Gadfly

# %%
plot([x -> sin(x) / x], 0, 50)
# Out:
# Plot(...)
